# %%
import matplotlib.pyplot as plt

soil_features = [
    "moisture",
    "ph",
    "organic_matter",
    "nitrogen",
    "phosphorus",
    "potassium"
]

structured_data[soil_features].describe()

# %%
import matplotlib.pyplot as plt

soil_features = [
    "moisture",
    "ph",
    "organic_matter",
    "nitrogen",
    "phosphorus",
    "potassium"
]

structured_data[soil_features].describe()

# %%
#BASIC EDAimport matplotlib.pyplot as plt

soil_features = [
    "moisture",
    "ph",
    "organic_matter",
    "nitrogen",
    "phosphorus",
    "potassium"
]

structured_data[soil_features].describe()

# %%
structured_data[soil_features].boxplot(
    figsize=(12, 6)
)

plt.title("Soil Test Parameter Distribution")
plt.ylabel("Value")
plt.xticks(rotation=45)
plt.show()

# %%
from pathlib import Path

processed_path = Path("../data/soil_tests/processed")
processed_path.mkdir(parents=True, exist_ok=True)

clean_file = processed_path / "clean_soil_test_data.csv"

structured_data.to_csv(
    clean_file,
    index=False
)

print("Clean dataset saved successfully")
print("File:", clean_file)
print("Rows:", len(structured_data))
print("Columns:", len(structured_data.columns))
